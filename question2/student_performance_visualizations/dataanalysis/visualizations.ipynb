# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/StudentsPerformance.csv')
sns.set(style='whitegrid')

# %%
# 1. Histogram of Math Scores
plt.figure(figsize=(10, 6))
sns.histplot(df['math score'], bins=20, kde=True, color='blue')
plt.title('Distribution of Math Scores')
plt.xlabel('Math Score')
plt.ylabel('Frequency')
plt.savefig('histogram_math_scores.png')
plt.show()

# %%
# 2. Bar Chart of Average Scores by Gender
avg_scores_by_gender = df[['gender', 'math score', 'reading score', 'writing score']].groupby('gender').mean().reset_index()
plt.figure(figsize=(10, 6))
avg_scores_by_gender.plot(x='gender', kind='bar', color=['blue', 'orange', 'green'])
plt.title('Average Scores by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Score')
plt.xticks(rotation=0)
plt.legend(title='Subjects', labels=['Math', 'Reading', 'Writing'])
plt.savefig('bar_gender_performance.png')
plt.show()

# %%
# 3. Boxplot of Writing Scores by Parental Education Level
plt.figure(figsize=(12, 6))
sns.boxplot(x='parental level of education', y='writing score', data=df)
plt.title('Writing Scores by Parental Education Level')
plt.xticks(rotation=45)
plt.xlabel('Parental Level of Education')
plt.ylabel('Writing Score')
plt.savefig('boxplot_writing_scores.png')
plt.show()

# %%
# 4. Scatter Plot of Math vs. Reading Scores
plt.figure(figsize=(10, 6))
sns.scatterplot(x='math score', y='reading score', data=df, hue='gender', alpha=0.7)
plt.title('Scatter Plot of Math vs. Reading Scores')
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.legend(title='Gender')
plt.savefig('scatter_math_reading.png')
plt.show()

# %%
# 5. Heatmap of Score Correlations
plt.figure(figsize=(8, 6))
correlation_matrix = df[['math score', 'reading score', 'writing score']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Scores')
plt.savefig('heatmap_correlations.png')
plt.show()
